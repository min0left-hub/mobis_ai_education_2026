# %% [markdown]
# <a href="https://colab.research.google.com/github/min0left-hub/mobis_ai_education_2026/blob/main/DL_3_A_NN_backpropagation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## library load

# %%
# Importing 'numpy' library
import numpy as np
import pandas as pd
# Importing 'matplotlib' library to plot experimental results in form of figures
import matplotlib.pyplot as plt

# %% [markdown]
# ## DATA LOAD

# %%
input_set_for_training = np.array([[1, 1, 1], [1, 0, 1], [0, 0, 1], [0, 1, 1]])
output_set_for_training = np.array([[1, 1, 0, 0]]).T

# %%
pd.DataFrame(input_set_for_training)
# Out:
#    0  1  2
# 0  1  1  1
# 1  1  0  1
# 2  0  0  1
# 3  0  1  1

# %%
pd.DataFrame(output_set_for_training)
# Out:
#    0
# 0  1
# 1  1
# 2  0
# 3  0

# %% [markdown]
# ## MODEL DEFINITION

# %%
# 3층 신경망(입력층-은닉층-출력층) 클래스 정의
class ThreeLayersNeuralNetwork():
    def __init__(self):
        # 난수 시드 고정: 실행할 때마다 동일한 난수가 생성되어 디버깅에 유리
        np.random.seed(1)

       # 3층 신경망 구조:
        # - 입력층(Layer 0): 특성 3개
        # - 은닉층(Layer 1): 뉴런 4개
        # - 출력층(Layer 2): 뉴런 1개

        # 입력층(3) -> 은닉층(4) 가중치 초기화
        # 가중치 값의 범위: [-1, 1]
        # 형태: (3 x 4) = 입력 3개 × 은닉 4개
        self.weights_0_1 = 2 * np.random.random((3, 4)) - 1

        # 은닉층(4) -> 출력층(1) 가중치 초기화
        # 가중치 값의 범위: [-1, 1]
        # 형태: (4 x 1) = 은닉 4개 × 출력 1개
        self.weights_1_2 = 2 * np.random.random((4, 1)) - 1

        # 학습/추론 시 출력층의 값을 보관할 변수(행렬)
        self.layer_2 = np.array([])
        losses = []

     # 시그모이드 활성화 함수: 값을 (0,1) 범위로 정규화
    def normalizing_results(self, x):
        return 1 / (1 + np.exp(-x))

    # 시그모이드의 도함수: a * (1 - a)  (여기서 a는 시그모이드 출력)
    # 역전파 시 가중치 보정 크기(기울기)를 계산할 때 사용
    def derivative_of_sigmoid(self, x):
        return x * (1 - x)

    # 학습 후/중 추론(순전파) 실행 함수
    def run_nn(self, set_of_inputs):
        # 순전파: 입력 -> 은닉 -> 출력
        # 각 층에서 선형결합(dot) 후 시그모이드로 비선형 변환
        layer_0 = set_of_inputs  # matrix 1x3
        layer_1 = self.normalizing_results(np.dot(layer_0, self.weights_0_1))  # matrix 1x3 * matrix 3x4 = matrix 1x4
        layer_2 = self.normalizing_results(np.dot(layer_1, self.weights_1_2))  # matrix 1x4 * matrix 4x1 = matrix 1x1
        return layer_2

    # 신경망 학습(역전파 포함)
    def training_process(self, set_of_inputs_for_training, set_of_outputs_for_training, iterations):
        # 지정된 반복 횟수만큼 에폭 반복
        for i in range(iterations):
             # 1) 순전파: 입력 -> 은닉 -> 출력
            # numpy.dot으로 층의 값과 가중치를 행렬 곱해 선형결합 수행
            layer_0 = set_of_inputs_for_training  # matrix 4x3
            layer_1 = self.normalizing_results(np.dot(layer_0, self.weights_0_1))  # matrix 4x3 * matrix 3x4 = matrix 4x4
            self.layer_2 = self.normalizing_results(np.dot(layer_1, self.weights_1_2))  # matrix 4x4 * matrix 4x1 = matrix 4x1

            # 2) 출력층 오차: (정답 - 예측)
            # 형태: (4 x 1) - (4 x 1) = (4 x 1)
            layer_2_error = set_of_outputs_for_training - self.layer_2

            # 100번마다 평균 절대오차를 출력(학습 경향 관찰용)
            # (분석 전 출력 과다 방지를 원하면 이 부분을 주석 처리)
            if (i % 100) == 0:
                print('Final error after', i, 'iterations =', np.mean(np.abs(layer_2_error)))
                loss=np.mean(np.abs(layer_2_error))
                losses.append(loss)
                # 실시간 그래프 출력
                # clear_output(wait=True)
                line.set_xdata(range(len(losses)))
                line.set_ydata(losses)

                ax.relim()           # 축 범위 재계산
                ax.autoscale_view() # 스케일 자동 조정

                fig.canvas.draw()
                fig.canvas.flush_events()

                print("Iteration:", i)
                print("Loss:", loss)


            # 3) 출력층 델타(delta_2) 계산: 오차 × 시그모이드 도함수
            # 여기서는 원소별 곱(element-wise)을 사용('*'), dot(행렬곱)이 아님
            # 예) [[1],[1],[1],[1]] * [[2],[3],[4],[5]] = [[2],[3],[4],[5]]

            delta_2 = layer_2_error * self.derivative_of_sigmoid(self.layer_2)

            # 4) 은닉층 오차: delta_2를 출력층 가중치로 역전파
            # delta_2 · W(은닉->출력)^T  => (4x1)·(1x4)=(4x4)
            # (각 샘플의 은닉 노드별 오차 기여도)
            layer_1_error = np.dot(delta_2, self.weights_1_2.T)

            # 5) 은닉층 델타(delta_1): 은닉층 오차 × 시그모이드 도함수
            delta_1 = layer_1_error * self.derivative_of_sigmoid(layer_1)

            # 6) 가중치 업데이트
            # 은닉->출력 가중치: (4x4)^T·(4x1) = (4x1)
            self.weights_1_2 += np.dot(layer_1.T, delta_2)
            # 입력->은닉 가중치: (4x3)^T·(4x4) = (3x4)
            self.weights_0_1 += np.dot(layer_0.T, delta_1)
    def show_model(self):
        print("=== Neural Network Architecture ===")
        print(f"Input Layer   : 3 nodes")
        print(f"Hidden Layer  : 4 nodes (Activation: Sigmoid)")
        print(f"Output Layer  : 1 node  (Activation: Sigmoid)")
        print("----------------------------------")
        print(f"Weights Input → Hidden : {self.weights_0_1.shape}")
        print(f"Weights Hidden → Output: {self.weights_1_2.shape}")

# %% [markdown]
# ## CHECK MODEL

# %%
three_layers_neural_network = ThreeLayersNeuralNetwork()
model = ThreeLayersNeuralNetwork()
model.show_model()
# Out:
# === Neural Network Architecture ===
# Input Layer   : 3 nodes
# Hidden Layer  : 4 nodes (Activation: Sigmoid)
# Output Layer  : 1 node  (Activation: Sigmoid)
# ----------------------------------
# Weights Input → Hidden : (3, 4)
# Weights Hidden → Output: (4, 1)

# %%
#   초기(학습 전) 가중치를 확인합니다.
#        아래는 입력층(Layer 0) → 은닉층(Layer 1) 사이의 가중치 행렬을 출력.
#        모양(shape)은 (3 x 4): 입력 특성 3개 × 은닉 뉴런 4개.
#        각 값은 ∈ [-1, 1] 범위의 난수로 초기화.
print('Weights 0-1')
print(three_layers_neural_network.weights_0_1)
print()

#        은닉층(Layer 1) → 출력층(Layer 2) 사이의 가중치 행렬을 출력.
#        모양(shape)은 (4 x 1): 은닉 뉴런 4개 × 출력 뉴런 1개.
#        역시 초기 상태이므로 학습 전 무작위 값.
print('Weights 1-2')
print(three_layers_neural_network.weights_1_2)
print()
# Out:
# Weights 0-1
# [[-0.16595599  0.44064899 -0.99977125 -0.39533485]
#  [-0.70648822 -0.81532281 -0.62747958 -0.30887855]
#  [-0.20646505  0.07763347 -0.16161097  0.370439  ]]
#
# Weights 1-2
# [[-0.5910955 ]
#  [ 0.75623487]
#  [-0.94522481]
#  [ 0.34093502]]

# %% [markdown]
# ## LEARNING

# %%
# 신경망 학습:
# 마지막 인자 5000은 반복 횟수(iterations)로, 순전파/역전파를 5000번 수행합니다.
# 내부적으로는:
#   1) 순전파: layer_0 → layer_1 → layer_2
#   2) 오차 계산: (타겟 - 예측)
#   3) 역전파: delta 계산 후, 가중치(weights_0_1, weights_1_2) 갱신
#  을 반복하여 출력이 타겟에 근접하도록 가중치를 조정.
losses=[]
plt.ion()  # interactive mode ON
fig, ax = plt.subplots()
line, = ax.plot([], [], label="Loss")
ax.set_xlabel("Iteration")
ax.set_ylabel("Loss")
ax.set_title("Training Loss")
ax.legend()
ax.grid(True)
three_layers_neural_network.training_process(input_set_for_training, output_set_for_training, 5000)

# 학습이 끝난 뒤, 최종 출력(layer_2)을 확인합니다.
# layer_2는 시그모이드 출력을 사용하므로 (0,1) 범위의 실수이며,
# 이진 분류처럼 사용하려면 보통 0.5 기준으로 0/1 판정을 합니다.

print()
print('Output results after training:')
print(three_layers_neural_network.layer_2)
print()
# Out:
# Final error after 0 iterations = 0.4685343254580603
# Iteration: 0
# Loss: 0.4685343254580603
# Final error after 100 iterations = 0.08510112841108156
# Iteration: 100
# Loss: 0.08510112841108156
# Final error after 200 iterations = 0.050132734758316685
# Iteration: 200
# Loss: 0.050132734758316685
# Final error after 300 iterations = 0.03797087740364832
# Iteration: 300
# Loss: 0.03797087740364832
# Final error after 400 iterations = 0.03149062516111875
# Iteration: 400
# Loss: 0.03149062516111875
# Final error after 500 iterations = 0.02735966511749842
# Iteration: 500
# Loss: 0.02735966511749842
# Final error after 600 iterations = 0.02445034444334141
# Iteration: 600
# Loss: 0.02445034444334141
# Final error after 700 iterations = 0.022266879001479455
# Iteration: 700
# Loss: 0.022266879001479455
# Final error after 800 iterations = 0.020554254179831824
# Iteration: 800
# Loss: 0.020554254179831824
# Final error after 900 iterations = 0.019166688164028403
# Iteration: 900
# Loss: 0.019166688164028403
# Final error after 1000 iterations = 0.018014239352682856
# Iteration: 1000
# Loss: 0.018014239352682856
# Final error after 1100 iterations = 0.017038116699773957
# Iteration: 1100
# Loss: 0.017038116699773957
# Final error after 1200 iterations = 0.01619810821079787
# Iteration: 1200
# Loss: 0.01619810821079787
# Final error after 1300 iterations = 0.015465685352658543
# Iteration: 1300
# Loss: 0.015465685352658543
# Final error after 1400 iterations = 0.014819989558180535
# Iteration: 1400
# Loss: 0.014819989558180535
# Final error after 1500 iterations = 0.014245380154921867
# Iteration: 1500
# Loss: 0.014245380154921867
# Final error after 1600 iterations = 0.013729874476290867
# Iteration: 1600
# Loss: 0.013729874476290867
# Final error after 1700 iterations = 0.01326412099197563
# Iteration: 1700
# Loss: 0.01326412099197563
# Final error after 1800 iterations = 0.01284070318034915
# Iteration: 1800
# Loss: 0.01284070318034915
# Final error after 1900 iterations = 0.012453655436013723
# Iteration: 1900
# Loss: 0.012453655436013723
# Final error after 2000 iterations = 0.012098118827883314
# Iteration: 2000
# Loss: 0.012098118827883314
# Final error after 2100 iterations = 0.011770091429135359
# Iteration: 2100
# Loss: 0.011770091429135359
# Final error after 2200 iterations = 0.011466244030063705
# Iteration: 2200
# Loss: 0.011466244030063705
# Final error after 2300 iterations = 0.011183781954620622
# Iteration: 2300
# Loss: 0.011183781954620622
# Final error after 2400 iterations = 0.010920339967303055
# Iteration: 2400
# Loss: 0.010920339967303055
# Final error after 2500 iterations = 0.010673901313210884
# Iteration: 2500
# Loss: 0.010673901313210884
# Final error after 2600 iterations = 0.01044273461608785
# Iteration: 2600
# Loss: 0.01044273461608785
# Final error after 2700 iterations = 0.010225344166926251
# Iteration: 2700
# Loss: 0.010225344166926251
# Final error after 2800 iterations = 0.01002043037570152
# Iteration: 2800
# Loss: 0.01002043037570152
# Final error after 2900 iterations = 0.009826858023068442
# Iteration: 2900
# Loss: 0.009826858023068442
# Final error after 3000 iterations = 0.009643630560125675
# Iteration: 3000
# Loss: 0.009643630560125675
# Final error after 3100 iterations = 0.009469869142600413
# Iteration: 3100
# Loss: 0.009469869142600413
# Final error after 3200 iterations = 0.009304795403940264
# Iteration: 3200
# Loss: 0.009304795403940264
# Final error after 3300 iterations = 0.00914771720544131
# Iteration: 3300
# Loss: 0.00914771720544131
# Final error after 3400 iterations = 0.008998016774987789
# Iteration: 3400
# Loss: 0.008998016774987789
# Final error after 3500 iterations = 0.008855140776037978
# Iteration: 3500
# Loss: 0.008855140776037978
# Final error after 3600 iterations = 0.008718591946936378
# Iteration: 3600
# Loss: 0.008718591946936378
# Final error after 3700 iterations = 0.00858792202581032
# Iteration: 3700
# Loss: 0.00858792202581032
# Final error after 3800 iterations = 0.008462725734184837
# Iteration: 3800
# Loss: 0.008462725734184837
# Final error after 3900 iterations = 0.008342635637366275
# Iteration: 3900
# Loss: 0.008342635637366275
# Final error after 4000 iterations = 0.008227317734746435
# Iteration: 4000
# Loss: 0.008227317734746435
# Final error after 4100 iterations = 0.008116467660809219
# Iteration: 4100
# Loss: 0.008116467660809219
# Final error after 4200 iterations = 0.00800980739951019
# Iteration: 4200
# Loss: 0.00800980739951019
# Final error after 4300 iterations = 0.007907082432145822
# Iteration: 4300
# Loss: 0.007907082432145822
# Final error after 4400 iterations = 0.0078080592528175135
# Iteration: 4400
# Loss: 0.0078080592528175135
# Final error after 4500 iterations = 0.007712523196874705
# Iteration: 4500
# Loss: 0.007712523196874705
# Final error after 4600 iterations = 0.00762027653686475
# Iteration: 4600
# Loss: 0.00762027653686475
# Final error after 4700 iterations = 0.007531136807960144
# Iteration: 4700
# Loss: 0.007531136807960144
# Final error after 4800 iterations = 0.00744493533093466
# Iteration: 4800
# Loss: 0.00744493533093466
# Final error after 4900 iterations = 0.0073615159057695435
# Iteration: 4900
# Loss: 0.0073615159057695435
#
# Output results after training:
# [[0.99181271]
#  [0.9926379 ]
#  [0.00744159]
#  [0.00613513]]

# %%
# 단일 테스트 입력에 대한 신경망의 예측값을 출력합니다.
#  np.array([1, 0, 0])은 길이 3의 입력 벡터입니다.
#  이 구현에서는 학습 시 마지막 특성(세 번째 값)을 'bias=1'로 두는 bias trick을 썼는데,
#  여기서는 0을 넣었기 때문에 학습 때와 조건이 달라집니다(출력이 달라질 수 있음).
#  학습 조건과 동일하게 시험하려면 보통 np.array([1, 0, 1])처럼 마지막 값을 1로 둡니다.
#   run_nn(...)은 순전파(입력→은닉→출력)를 수행해 시그모이드(0~1) 범위의 값을 반환합니다.
#   이 값은 확률처럼 해석할 수 있으며, 이진 분류에선 통상 0.5를 기준으로 0/1 판정을 합니다.
#
print('Output result for testing data = ', three_layers_neural_network.run_nn(np.array([1, 0, 0])))
# Out:
# Output result for testing data =  [0.99619533]

# %% [markdown]
# ## Result

# %%
x=[1,2,3,4]
y_gt=[1, 1, 0, 0]
y_pred=three_layers_neural_network.run_nn(input_set_for_training)

# %%
# 데이터의 분포를 그래프 플롯팅
plt.scatter(x, y_gt ,label='Ground truth')
plt.scatter(x, y_pred, label='Prediction')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.legend()
plt.show()

# %%
#
